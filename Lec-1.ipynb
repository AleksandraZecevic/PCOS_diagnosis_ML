# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
a = 5
b = 6
a+b
# Out:
# 11

# %%
_*10
# Out:
# 110

# %% [markdown]
# # This is H1
# some *italic* text
# ## this is H2
# some **bold** text
# ### this is H3
# some text with a [link](http://markotkalcic.com)
# an equation:
# $$m(X) = {\sum_{i=1}ˆI x_i \over N}$$
# an image
# ![Caption](C:\Users\PC-2\Desktop\Slike\howl.jpg)
# and some syntax-highlighted code in Python
# \```python
# print('Hello, world')
# \```
# and in Java
# \```java
# public void catchMeIfYouCan(Integer a){
# System.ou.println(a);
# }
# \```

# %%
my_str="Hello World!"
type(my_str)

my_str[6:11]
# Out:
# 'World'
